# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
with h5py.File('DATA/target_model.h5') as f:
    x = f['x'][:]
    y = f['y'][:]
    z = f['z'][:]
    vs = f['vs'][:]

# %%
plt.pcolor(x, z, vs[:, len(y)//2, :].T, cmap='jet')

# %%
plt.pcolor(y, z, vs[len(x)//2, :, :].T, cmap='jet_r')
